# %% [markdown]
# <a href="https://colab.research.google.com/github/mcjkurz/qhchina/blob/main/tutorials/Intro_to_Python_for_Chinese_Humanities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python for Chinese Humanities

# %%
text = "Welcome to the tutorial!"
print(text)
# Out:
# Welcome to the tutorial!

# %%
# we first define a variable (變數) and use it later

text = "這是一個字串"
age = 18
temperature = 31.2
is_raining = True
names = ["Takeshi", "John", "Piotr", "Shervin"]

print(temperature)
# Out:
# 31.2

# %%
temperature = 31.2
print("現在溫度：", temperature)
print("溫度是否高於35度？")
print(temperature > 35)

# let's change the temperature now. It is getting hotter!
temperature = 38.4
print("天氣越來越熱。現在溫度：", temperature)
print("溫度是否高於35度？")
print(temperature > 35)

# it is raining, and temperature suddenly drops by 10 degrees
temperature = temperature - 10
print("下雨了！現在溫度：", temperature)
print("溫度是否高於35度？")
print(temperature > 35)

# after the rain, the sun has come out. It is warmer again
temperature += 7
print("太陽出來了。現在溫度：", temperature)
print("溫度是否高於35度？")
print(temperature > 35)
# Out:
# 現在溫度： 31.2
# 溫度是否高於35度？
# False
# 天氣越來越熱。現在溫度： 38.4
# 溫度是否高於35度？
# True
# 下雨了！現在溫度： 28.4
# 溫度是否高於35度？
# False
# 太陽出來了。現在溫度： 35.4
# 溫度是否高於35度？
# True

# %%
names = ["Takeshi", "John", "Piotr", "Shervin"]
print(names[2])
# Out:
# Piotr

# %%
i = 0
while i < 5:
  print(i)
  i = i + 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for k in [0, 1, 2, 3, 4]:
  print(k)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for s in range(5):
  print(s)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for name in names:
  print(name)
# Out:
# Takeshi
# John
# Piotr
# Shervin

# %%
text = "我今天很開心"
# for the computer, this is *almost* like
# text = ["我","今","天","很","開","心"]
# a list of characters

print("text有", len(text), "個漢字。")
# Out:
# text 有 6 個漢字。

# %%
i = 0
for character in text:
  print(i, character)
  i = i + 1
# Out:
# 0 我
# 1 今
# 2 天
# 3 很
# 4 開
# 5 心

# %%
for i, character in enumerate(text):
  print(i, character)
# Out:
# 0 我
# 1 今
# 2 天
# 3 很
# 4 開
# 5 心

# %%
print(text[3]) # print the character at index 3 (the 4th character; indexing starts from 0)
# Out:
# 很

# %%
text = "我今天跟開心"
word_list = ["我", "今天", "很", "開心"]
print("word_list有", len(word_list), "個詞。")
# Out:
# word_list有 4 個詞。

# %%
for i, word in enumerate(word_list):
  print(i, word)
# Out:
# 0 我
# 1 今天
# 2 很
# 3 開心

# %%
# !python -m spacy download zh_core_web_sm
import spacy
nlp = spacy.load("zh_core_web_sm")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 MB 8.4 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('zh_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy
from spacy.tokenizer import Tokenizer
from spacy.tokens import Doc
# Test the tokenizer
doc = nlp("我今天很開心")
print([token.text for token in doc])
# Out:
# ['我', '今天', '很', '開心']

# %%
words = [word.text for word in nlp("我今天很開心")]
print(words)
# Out:
# ['我', '今天', '很', '開心']

# %%
# !wget https://raw.githubusercontent.com/mcjkurz/qhchina/main/tutorials/data/张爱玲_倾城之恋.txt
# Out:
# --2024-06-14 06:55:11--  https://raw.githubusercontent.com/mcjkurz/qhchina/main/tutorials/data/%E5%BC%A0%E7%88%B1%E7%8E%B2_%E5%80%BE%E5%9F%8E%E4%B9%8B%E6%81%8B.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79834 (78K) [text/plain]
# Saving to: ‘张爱玲_倾城之恋.txt’
#
# 张爱玲_倾城之恋.txt 100%[===================>]  77.96K  --.-KB/s    in 0.02s
#
# 2024-06-14 06:55:12 (3.34 MB/s) - ‘张爱玲_倾城之恋.txt’ saved [79834/79834]

# %%
f = open("张爱玲_倾城之恋.txt", "r")
novel_text = f.read()
f.close()
words = [word.text for word in nlp(novel_text) if word.pos_ not in ["PUNCT", "PROPN"]]

# %%
counts = [(word, words.count(word) / len(words)) for word in set(words)]

# %%
word_freqs = [line.strip().split() for line in open("words_freqs.txt", "r").readlines() if len(line.split()) == 2]

# %%
word_freqs = [(word, int(freq)) for word, freq in word_freqs]
sum_total = sum(freq for word, freq in word_freqs)
word_freqs = [(word, freq/sum_total) for word,freq in word_freqs]

# %%
counts = {k:v for k,v in counts}

# %%
word_freqs = {k:v for k,v in word_freqs}

# %%
counts_compared = {k:counts[k]/word_freqs[k] for k in counts.keys() if k in word_freqs.keys() and words.count(k) > 5}
print(len(counts_compared))
# Out:
# 303

# %%
wordcloud_data = sorted(counts_compared.items(), key=lambda r : r[-1], reverse=True)[2:300]
wordcloud_data[:50]
# Out:
# [('太太', 369.1226117622935),
#  ('旗袍', 105.46444307093451),
#  ('老太太', 99.76592146552584),
#  ('搁', 84.48657997862367),
#  ('方才', 78.00577759294306),
#  ('呃', 60.47150536998684),
#  ('旅馆', 57.23761239649843),
#  ('奶奶', 56.697617404277715),
#  ('底下', 52.77625992875385),
#  ('只怕', 48.5120818112467),
#  ('可不', 44.70567146093514),
#  ('屋子', 43.27932338948329),
#  ('只得', 42.62361764440168),
#  ('罢', 38.86139289960686),
#  ('糊涂', 38.45081846881072),
#  ('阳台', 36.233647899308856),
#  ('饭店', 35.13836850906754),
#  ('一同', 34.015378098862634),
#  ('隔壁', 33.70471288796205),
#  ('那边', 29.805627143326706),
#  ('听见', 28.44138143763428),
#  ('镜子', 27.10851566738254),
#  ('小姐', 26.608895348294865),
#  ('替', 26.102824846983765),
#  ('柳', 24.40980463304735),
#  ('肯', 21.587093397980457),
#  ('瞧', 21.448355070385066),
#  ('从前', 19.579675498407266),
#  ('渐渐', 19.572270079722244),
#  ('仿佛', 18.96049625946408),
#  ('完了', 18.442624424029827),
#  ('哪儿', 18.374655111532793),
#  ('原', 17.652394694512253),
# ...

# %%
# !pip install git+https://github.com/Hsins/mpl-tc-fonts.git
import matplotlib.pyplot as plt
import mpl_tc_fonts
mpl_tc_fonts.load_font('cwtex', 'copy')
mpl_tc_fonts.set_font('Noto Sans CJK TC')
print(mpl_tc_fonts.scan_font('國'))
mpl_tc_fonts.set_font()
# Out:
# ...
#   Cloning https://github.com/Hsins/mpl-tc-fonts.git to /tmp/pip-req-build-1pv8cslr
#   Running command git clone --filter=blob:none --quiet https://github.com/Hsins/mpl-tc-fonts.git /tmp/pip-req-build-1pv8cslr
#   Resolved https://github.com/Hsins/mpl-tc-fonts.git to commit 0cc159a2dbf1eb199f0bd847eabfee75403346b6
#   Preparing metadata (setup.py) ... done
# ...
# ['Noto Serif CJK TC', 'Noto Sans CJK TC', 'cwTeX Q Fangsong', 'cwTeX Q Hei', 'cwTeX Q Kai', 'cwTeX Q Ming', 'cwTeX Q Yuan']

# %%
import numpy as np
from PIL import Image

# The Image shape in which you wanna convert it to.
mask = np.array(Image.open('hat.jpg'))

from wordcloud import WordCloud
import matplotlib.pyplot as plt
wordcloud_data = sorted(counts_compared.items(), key=lambda r : r[-1], reverse=True)[2:300]

# Convert to a dictionary
frequencies_dict = dict(wordcloud_data)

# Generate word cloud
wordcloud = WordCloud(font_path='STHeiti Medium (2).ttc', max_words=500, mask=mask, width=1200, height=1200,
                      background_color='white')

wordcloud.generate_from_frequencies(frequencies_dict)

# Display the generated word cloud
plt.figure(figsize=(10, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
